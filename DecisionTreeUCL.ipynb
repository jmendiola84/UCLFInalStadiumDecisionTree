# %%
from sklearn.cross_validation import train_test_split 
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from lightgbm import create_tree_digraph
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report

# %%
stadiums_csv = "UEFA_Stadiums_Geo_Data_UTF8.csv"
stadiums_df = pd.read_csv(stadiums_csv)
stadiums_df.dtypes
# Out:
# Unnamed: 0              int64
# Confederation          object
# Stadium                object
# City                   object
# HomeTeams              object
# Capacity                int64
# Country                object
# IOC                    object
# Population              int64
# UCLChampions             bool
# UELChampion              bool
# UCLFinalStadium          bool
# UELFinalStadium          bool
# Capacidad/1000Habs    float64
# Latitude              float64
# Longitude             float64
# dtype: object

# %%
stadiums_df = stadiums_df.drop(['Unnamed: 0','Confederation','City','HomeTeams','IOC','Capacidad/1000Habs','Latitude', 'Longitude'], axis=1)

stadiums_df.head()
# Out:
#                     Stadium  Capacity  Country  Population  UCLChampions  \
# 0       Stadiumi Besëlidhja      7000  Albania     2876591         False
# 1       Stadiumi Flamurtari      8200  Albania     2876591         False
# 2             Stadiumi Laçi      5000  Albania     2876591         False
# 3      Stadiumi Niko Dovana     12040  Albania     2876591         False
# 4  Stadiumi Selman Stërmasi      9500  Albania     2876591         False
#
#    UELChampion  UCLFinalStadium   UELFinalStadium
# 0        False             False            False
# 1        False             False            False
# 2        False             False            False
# 3        False             False            False
# 4        False             False            False

# %%
X = stadiums_df.values[:, [1,3,4]]
Y = stadiums_df.values[:, 6]
Y=Y.astype('int')

# %%
X_train, X_test, y_train, y_test = train_test_split(  
    X, Y, test_size = 0.3, random_state = 100)

# %%
#clf_gini = DecisionTreeClassifier(criterion = "gini", 
          #  random_state = 100, max_depth=3, min_samples_leaf=5) 
  
    # Performing training #
#clf_gini.fit(X_train, y_train)
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)

# %%
import graphviz 
dot_data = tree.export_graphviz(
    clf, out_file=None, 
    feature_names=['Stadium Size','Country Population','UCLChampions'],  
    class_names=['No Candidate','Candidate'],  
    filled=True, rounded=True,  
    special_characters=True)  

import pydotplus
graph = pydotplus.graph_from_dot_data(dot_data)
graph.write_png('UCLDecisionTree.png')

graph = graphviz.Source(dot_data)  
graph

# %%
for (idx, row) in stadiums_df.iterrows():
    try:
    
        if (row.loc['Country']) == "Germany":
            #Store current row value for each column
            stadium = (row.loc['Stadium'])
            capacity = (row.loc['Capacity'])
            population = (row.loc['Population'])
            UCLChampion = (row.loc['UCLChampions'])
            y_pred = clf.predict([[capacity, population, UCLChampion]]) 
            y_pred_proba = clf.predict_proba([[capacity, population, UCLChampion]])
            print("Predicted values for "+stadium+":") 
            print(y_pred)
            print(y_pred_proba)
    except:
        #Print to verify when a city is not found
        print("Not found")
        #Count to validate how many cities were not found
        continue
# Out:
# Predicted values for Alfred-Kunze-Sportpark:
# [0]
# [[ 1.  0.]]
# Predicted values for Allianz Arena:
# [1]
# [[ 0.  1.]]
# Predicted values for Alte Försterei:
# [0]
# [[ 1.  0.]]
# Predicted values for Audi-Sportpark:
# [0]
# [[ 1.  0.]]
# Predicted values for Auestadion:
# [0]
# [[ 1.  0.]]
# Predicted values for BayArena:
# [0]
# [[ 1.  0.]]
# Predicted values for Benteler-Arena:
# [0]
# [[ 1.  0.]]
# Predicted values for Borussia Park:
# [0]
# [[ 1.  0.]]
# Predicted values for Brita-Arena:
# [0]
# [[ 1.  0.]]
# Predicted values for Bruchwegstadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Carl-Benz-Stadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Commerzbank Arena:
# [0]
# [[ 1.  0.]]
# Predicted values for Continental Arena:
# [0]
# [[ 1.  0.]]
# Predicted values for Dietmar-Hopp-Stadion:
# [0]
# [[ 1.  0.]]
# Predicted values for DKB Arena:
# [0]
# [[ 1.  0.]]
# Predicted values for Donaustadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Eintracht-Stadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Ellenfeldstadion:
# [0]
# [[ 1.  0.]]
# Predicted values for ERDGAS Sportpark:
# [0]
# [[ 1.  0.]]
# Predicted values for Ernst-Abbe-Sportfeld:
# [0]
# [[ 1.  0.]]
# Predicted values for Erzgebirgsstadion:
# [0]
# [[ 1.  0.]]
# Predicted values for flyeralarm Arena:
# [0]
# [[ 1.  0.]]
# Predicted values for Frankenstadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Frankfurter Volksbank Stadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Franz-Kremer-Stadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Friedrich-Ebert-Stadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Friedrich-Ludwig-Jahn-Sportpark:
# [0]
# [[ 1.  0.]]
# Predicted values for Fritz-Walter-Stadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Gazi-Stadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Grenzland-Stadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Grotenburg:
# [0]
# [[ 1.  0.]]
# Predicted values for Grünwalder Stadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Hans-Walter-Wild-Stadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Hardtwaldstadion:
# [0]
# [[ 1.  0.]]
# Predicted values for HDI-Arena:
# [0]
# [[ 1.  0.]]
# Predicted values for Hermann-Löns-Stadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Holstein-Stadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Jahnstadion Göttingen:
# [0]
# [[ 1.  0.]]
# Predicted values for Jahnstadion Regensburg:
# [0]
# [[ 1.  0.]]
# Predicted values for Leimbachstadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Lohmühle:
# [0]
# [[ 1.  0.]]
# Predicted values for Lohrheidestadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Ludwig-Jahn-Stadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Ludwigsparkstadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Max-Morlock-Stadion:
# [0]
# [[ 1.  0.]]
# Predicted values for MDCC-Arena:
# [0]
# [[ 1.  0.]]
# Predicted values for mechatronik Arena:
# [0]
# [[ 1.  0.]]
# Predicted values for Mercedes-Benz Arena:
# [0]
# [[ 1.  0.]]
# Predicted values for Merck-Stadion am Böllenfalltor:
# [0]
# [[ 1.  0.]]
# Predicted values for Merkur Spiel-Arena:
# [0]
# [[ 1.  0.]]
# Predicted values for Millerntor-Stadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Olympiastadion Berlin:
# [1]
# [[ 0.  1.]]
# Predicted values for Olympiastadion Munich:
# [1]
# [[ 0.  1.]]
# Predicted values for Opel Arena:
# [0]
# [[ 1.  0.]]
# Predicted values for Osnatel-Arena:
# [0]
# [[ 1.  0.]]
# Predicted values for OSTALB Arena:
# [0]
# [[ 1.  0.]]
# Predicted values for Preußenstadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Red Bull Arena:
# [0]
# [[ 1.  0.]]
# Predicted values for Rhein-Neckar-Stadion:
# [0]
# [[ 1.  0.]]
# Predicted values for RheinEnergie Stadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Rosenaustadion:
# [0]
# [[ 1.  0.]]
# Predicted values for RSV-Stadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Rudolf-Harbig-Stadon:
# [0]
# [[ 1.  0.]]
# Predicted values for Schauinsland-Reisen-Arena:
# [0]
# [[ 1.  0.]]
# Predicted values for Schönebürgstadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Schüco Arena:
# [0]
# [[ 1.  0.]]
# Predicted values for Schwarzwald-Stadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Sepp-Herberger-Stadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Westfalenstadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Sparda-Bank-Hessen-Stadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Sportpark Höhenberg:
# [0]
# [[ 1.  0.]]
# Predicted values for Sportpark Ronhof:
# [0]
# [[ 1.  0.]]
# Predicted values for Stadion am Zoo:
# [0]
# [[ 1.  0.]]
# Predicted values for Stadion Chemnitz:
# [0]
# [[ 1.  0.]]
# Predicted values for Stadion der Freundschaft:
# [0]
# [[ 1.  0.]]
# Predicted values for Stadion Essen:
# [0]
# [[ 1.  0.]]
# Predicted values for Stadion Niederrhein:
# [0]
# [[ 1.  0.]]
# Predicted values for Stadion Oberwerth:
# [0]
# [[ 1.  0.]]
# Predicted values for Stadion Rote Erde:
# [0]
# [[ 1.  0.]]
# Predicted values for Stadion Zwickau:
# [0]
# [[ 1.  0.]]
# Predicted values for Steigerwaldstadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Südstadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Tivoli:
# [0]
# [[ 1.  0.]]
# Predicted values for Tönnies-Arena:
# [0]
# [[ 1.  0.]]
# Predicted values for Arena AufSchalke:
# [1]
# [[ 0.  1.]]
# Predicted values for VfL-Stadion am Elsterweg:
# [0]
# [[ 1.  0.]]
# Predicted values for Voith-Arena:
# [0]
# [[ 1.  0.]]
# Predicted values for Volksparkstadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Volkswagen Arena:
# [0]
# [[ 1.  0.]]
# Predicted values for Vonovia Ruhrstadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Waldstadion Homburg:
# [0]
# [[ 1.  0.]]
# Predicted values for Waldstadion Weismain:
# [0]
# [[ 1.  0.]]
# Predicted values for Walter-Mundorf-Stadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Weserstadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Wildparkstadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Willy-Sachs-Stadion:
# [0]
# [[ 1.  0.]]
# Predicted values for Wirsol Rhein-Neckar Arena:
# [0]
# [[ 1.  0.]]
# Predicted values for WWK Arena:
# [0]
# [[ 1.  0.]]

# %%
# Plot the training points

# Parameters
n_classes = 2
plot_colors = "ryb"
plot_step = 0.02


for i, color in zip(range(n_classes), plot_colors):
    idx = np.where(y_train == i)
    plt.scatter(X[idx, 0], X[idx, 1], c=color, label=[i],
                    cmap=plt.cm.RdYlBu, edgecolor='black', s=15)

plt.suptitle("Decision surface of a decision tree using paired features")
plt.legend(loc='lower right', borderpad=0, handletextpad=0)
plt.axis("tight")

plt.figure()
clf = DecisionTreeClassifier().fit(X_train, y_train)
#plot_tree(clf, filled=True)
#lightgbm.create_tree_digraph(clf, filled=True)
plt.show()
